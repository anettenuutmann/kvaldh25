# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting numpy<2.7,>=1.26.4 (from scipy)
#   Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Downloading scipy-1.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.0/35.0 MB 61.3 MB/s  0:00:006m0:00:0100:01
# Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 96.2 MB/s  0:00:00
# Installing collected packages: numpy, scipy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [scipy]32m1/2 [scipy]
# Successfully installed numpy-2.4.2 scipy-1.17.0
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from scipy.stats import ttest_ind
print(ttest_ind([3, 5, 4], [12, 16, 14]))
print(ttest_ind([3, 5, 4, 6, 5, 4], [12, 16, 14, 16, 15, 14]))
print(ttest_ind([13, 15, 14], [12, 16, 14]))

# pip install scipy
# Out:
# TtestResult(statistic=np.float64(-7.745966692414834), pvalue=np.float64(0.001496481055900334), df=np.float64(4.0))
# TtestResult(statistic=np.float64(-13.28422328310143), pvalue=np.float64(1.1168292456111315e-07), df=np.float64(10.0))
# TtestResult(statistic=np.float64(0.0), pvalue=np.float64(1.0), df=np.float64(4.0))
